# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib.ticker import PercentFormatter
matplotlib.interactive(True)

plt.ion()
matplotlib.is_interactive()
with open('nobel.csv','r') as f:
    Data = pd.read_csv(f)
    Data['female_winner'] = Data['sex'] == 'Female'
    Data['decade'] = (np.floor(Data['year']/10)*10).astype(int) 
    physics = Data.groupby(['category', 'decade'],as_index=False)['female_winner'].mean()
    print(physics['category'])
    plt.rcParams['figure.figsize'] = [11, 7]
    ax = sns.lineplot(
        x = 'decade',
        y = 'female_winner',
        data = physics,
        hue = 'category'
    )
    
    ax.yaxis.set_major_formatter(PercentFormatter())
    plt.grid()
# Out:
# 0     Chemistry
# 1     Chemistry
# 2     Chemistry
# 3     Chemistry
# 4     Chemistry
#         ...
# 61      Physics
# 62      Physics
# 63      Physics
# 64      Physics
# 65      Physics
# Name: category, Length: 66, dtype: object
