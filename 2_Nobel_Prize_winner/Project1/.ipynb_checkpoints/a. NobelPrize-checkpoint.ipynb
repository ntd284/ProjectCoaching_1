# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from matplotlib.ticker import PercentFormatter


matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
with open("nobel.csv", 'r') as f:
    Data = pd.read_csv(f)
    Data['usa_born_winner'] = Data['birth_country'] == 'United States of America'
    Data['decade'] = (np.floor(Data['year']/10)*10).astype(int)
    
    
    prop_usa_winners_mean = Data.groupby(['decade'], as_index=False)['usa_born_winner'].mean() 
    prop_usa_winners_std = Data.groupby(['decade'], as_index=False)['usa_born_winner'].std()
    
#Define the confidence interval
#     print(prop_usa_winners_std)
    ci  =  prop_usa_winners_mean

      
    fig = plt.figure(figsize =(17,11))
    ax1 = fig.add_axes([0,0,1,1])
    ax1.plot(prop_usa_winners['decade'],
    prop_usa_winners['usa_born_winner'])
    
    plt.fill_between(prop_usa_winners_mean['decade'], abs(prop_usa_winners_mean['usa_born_winner']-ci), prop_usa_winners['usa_born_winner']+ci, color='blue', alpha=0.1)
    
    plt.xlabel('decade',fontsize=15,color='black')
    plt.ylabel('usa_born_winner',fontsize=15,color='black')

    ax1.yaxis.set_major_formatter(PercentFormatter(1.0))
    plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5044/2376810048.py in <module>
#      29     prop_usa_winners['usa_born_winner'])
#      30
# ---> 31     plt.fill_between(prop_usa_winners_mean['decade'], abs(prop_usa_winners_mean['usa_born_winner']-ci), prop_usa_winners['usa_born_winner']+ci, color='blue', alpha=0.1)
#      32
#      33     plt.xlabel('decade',fontsize=15,color='black')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2524         x, y1, y2=0, where=None, interpolate=False, step=None, *,
#    2525         data=None, **kwargs):
# -> 2526     return gca().fill_between(
#    2527         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
#    2528         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
